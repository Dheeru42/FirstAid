# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
ram = pd.read_csv('die.csv')
# ram.head(5)

# %%
o_df = {'Yes':1,'No':0}
o_d = {'Low':0,'High':2,'Normal':1}
g_od = {'Male':0,'Female':1}
ram['Fever'] = ram['Fever'].map(o_df)
ram['Cough'] = ram['Cough'].map(o_df)
ram['Fatigue'] = ram['Fatigue'].map(o_df)
ram['Difficulty Breathing'] = ram['Difficulty Breathing'].map(o_df)
ram['Blood Pressure'] = ram['Blood Pressure'].map(o_d)
ram['Cholesterol Level'] = ram['Cholesterol Level'].map(o_d)
ram['Gender'] = ram['Gender'].map(g_od)
ram.head()
# Out:
#        Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0    Influenza      1      0        1                     1   19       1
# 1  Common Cold      0      1        1                     0   25       1
# 2       Eczema      0      1        1                     0   25       1
# 3       Asthma      1      1        0                     1   25       0
# 4       Asthma      1      1        0                     1   25       0
#
#    Blood Pressure  Cholesterol Level Outcome Variable
# 0               0                  1         Positive
# 1               1                  1         Negative
# 2               1                  1         Negative
# 3               1                  1         Positive
# 4               1                  1         Positive

# %%
# Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ram['Disease'] = le.fit_transform(ram['Disease'])
ram.head()
# Out:
#    Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0       56      1      0        1                     1   19       1
# 1       24      0      1        1                     0   25       1
# 2       37      0      1        1                     0   25       1
# 3        6      1      1        0                     1   25       0
# 4        6      1      1        0                     1   25       0
#
#    Blood Pressure  Cholesterol Level Outcome Variable
# 0               0                  1         Positive
# 1               1                  1         Negative
# 2               1                  1         Negative
# 3               1                  1         Positive
# 4               1                  1         Positive

# %%
x = ram.iloc[:,:-1]
y = ram['Outcome Variable']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_test,y_test)*100,rfc.score(x_train,y_train)*100
# Out:
# (81.42857142857143, 100.0)

# %%
print('<---- Welcome To RAM Hospital Check Yourself From Disease ---->')
die = str(input("Enter Your Disease: "))
fever = int(input("Enter If Fever 1 else 0 : "))
cough = int(input("Enter If Cough 1 else 0 : "))
fatigue = int(input("Enter If Fatigue 1 else 0 : "))
db = int(input("Enter If Difficulty Breathing 1 else 0 : "))
age = int(input("Enter Your Age: "))
gender = int(input("Enter Gender For Male 0 or Female 1 : "))
bp = int(input("Enter Your Blood Pressure for Low 0,Normal 1 or High 2: "))
cl = int(input("Enter Your Cholesterol Level for Low 0,Normal 1 or High 2: "))
patient = [[die,fever,cough,fatigue,db,age,gender,bp,cl]]
# Out:
# <---- Welcome To RAM Hospital Check Yourself From Disease ---->
# Enter Your Disease: Common Cold
# Enter If Fever 1 else 0 : 1
# Enter If Cough 1 else 0 : 1
# Enter If Fatigue 1 else 0 : 0
# Enter If Difficulty Breathing 1 else 0 : 1
# Enter Your Age: 23
# Enter Gender For Male 0 or Female 1 : 0
# Enter Your Blood Pressure for Low 0,Normal 1 or High 2: 1
# Enter Your Cholesterol Level for Low 0,Normal 1 or High 2: 1

# %%
new_data = pd.DataFrame(patient,columns=x_train.columns)
new_data['Disease']=le.transform(new_data['Disease'])
result = rfc.predict(new_data)
# print(result)
if result == 'Negative':
  print(f"You Don't Have {die}")
else:
  print("Take An Medical Help Immediately!!!!")
# Out:
# Take An Medical Help Immediately!!!!
